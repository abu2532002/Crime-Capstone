# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

crime_data = pd.read_csv('01_District_wise_crimes_committed_IPC_2001_2012.csv')

# Select relevant features for clustering
selected_features = [
    'MURDER', 'ATTEMPT TO MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION',
    'DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT', 'RIOTS',
    'CRIMINAL BREACH OF TRUST', 'CHEATING', 'ARSON', 'HURT/GREVIOUS HURT',
    'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
    'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES'
]

# Extract selected features from the dataset
X = crime_data[selected_features]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine the optimal number of clusters (you can use the elbow method)
# Let's say you decide on 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
crime_data['Cluster'] = kmeans.fit_predict(X_scaled)

# Visualize the clusters (assuming you have a 3D plot)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

colors = {0: 'red', 1: 'blue', 2: 'green'}
ax.scatter(X_scaled[:, 0], X_scaled[:, 1], X_scaled[:, 2], c=crime_data['Cluster'].map(colors))

ax.set_xlabel(selected_features[0])
ax.set_ylabel(selected_features[1])
ax.set_zlabel(selected_features[2])
ax.set_title('Crime Clusters')

plt.show()

# Analyze the clusters and assign labels
cluster_labels = ['Sensitive Areas', 'Moderate Areas', 'Peaceful Areas']
crime_data['ClusterLabel'] = crime_data['Cluster'].map({i: cluster_labels[i] for i in range(len(cluster_labels))})

# Print the cluster details
cluster_details = crime_data.groupby('ClusterLabel').mean()[selected_features]
print(cluster_details)
# Out:
#                       MURDER  ATTEMPT TO MURDER         RAPE  \
# ClusterLabel
# Moderate Areas   2961.565789        2678.328947  1642.723684
# Peaceful Areas   1153.054264         920.418605   756.635659
# Sensitive Areas    48.940422          43.312188    29.030980
#
#                  KIDNAPPING & ABDUCTION     DACOITY      ROBBERY     BURGLARY  \
# ClusterLabel
# Moderate Areas              2530.368421  390.842105  1791.578947  7794.578947
# Peaceful Areas              1063.713178  209.155039   791.534884  3437.333333
# Sensitive Areas               43.598162    7.050953    29.308443   136.050159
#
#                         THEFT   AUTO THEFT        RIOTS  \
# ClusterLabel
# Moderate Areas   24726.763158  8448.105263  4983.776316
# Peaceful Areas   11230.527132  4380.806202  2783.705426
# Sensitive Areas    416.827962   151.334544    92.145824
#
#                  CRIMINAL BREACH OF TRUST     CHEATING       ARSON  \
# ClusterLabel
# Moderate Areas                1420.223684  6022.552632  812.407895
# Peaceful Areas                 499.395349  1974.193798  331.782946
# Sensitive Areas                 22.206423    93.373695   13.942919
#
#                  HURT/GREVIOUS HURT  DOWRY DEATHS  \
# ClusterLabel
# Moderate Areas         25597.000000    837.592105
# Peaceful Areas         10126.372093    189.798450
# Sensitive Areas          396.286655     10.697118
#
#                  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# ClusterLabel
# Moderate Areas                                         3277.250000
# Peaceful Areas                                         1367.883721
# Sensitive Areas                                          54.559918
#
#                  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# ClusterLabel
# Moderate Areas                           6754.447368
# Peaceful Areas                           2581.705426
# Sensitive Areas                           102.590104
#
#                  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES
# ClusterLabel
# Moderate Areas                                      7.684211
# Peaceful Areas                                      2.302326
# Sensitive Areas                                     0.102474

# %%
import pandas as pd
from sklearn.cluster import KMeans

features = crime_data[['MURDER', 'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION', 'DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']]

# Create and fit KMeans model
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
crime_data['Cluster'] = kmeans.fit_predict(features)

# Create DataFrames for each cluster
cluster_0_df = crime_data[crime_data['Cluster'] == 0]
cluster_1_df = crime_data[crime_data['Cluster'] == 1]
cluster_2_df = crime_data[crime_data['Cluster'] == 2]

# Display all rows in each cluster DataFrame
print("Cluster 0 DataFrame:")
print(cluster_0_df)

print("\nCluster 1 DataFrame:")
print(cluster_1_df)

print("\nCluster 2 DataFrame:")
print(cluster_2_df)
# Out:
# Cluster 0 DataFrame:
#        STATE/UT Name  District Name  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                            17    50               0
# 1                                             1    23               0
# 2                                             2    27               0
# 3                                             1    20               0
# 4                                             1    23               0
# ...                                         ...   ...             ...
# 9012                                          0     0               0
# 9013                                          0     0               0
# 9014                                          2     6               0
# 9015                                         10     7               0
# 9016                                         12    13               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  DOWRY DEATHS  \
# 0             50                      46  ...            16
# 1             23                      53  ...             7
# 2             27                      59  ...            14
# 3             20                      25  ...            17
# 4             23                      49  ...            12
# ...          ...                     ...  ...           ...
# 9012           0                       0  ...             0
# 9013           0                       0  ...             0
# 9014           6                       2  ...             0
# 9015           7                      17  ...             0
# 9016          13                      19  ...             0
#
#       ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0                                                   149
# 1                                                   118
# 2                                                   112
# 3                                                   126
# 4                                                   109
# ...                                                 ...
# 9012                                                  1
# 9013                                                  1
# 9014                                                  2
# 9015                                                  7
# 9016                                                  9
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                             34                                  175
# 1                             24                                  154
# 2                             83                                  186
# 3                             38                                   57
# 4                             58                                  247
# ...                          ...                                  ...
# 9012                           0                                    1
# 9013                           0                                    1
# 9014                           0                                    1
# 9015                           2                                    5
# 9016                           2                                    6
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 9012                                            0
# 9013                                            0
# 9014                                            0
# 9015                                            0
# 9016                                            0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES  \
# 0                             181              1518              4154
# 1                             270               754              4125
# 2                             404              1262              5818
# 3                             233              1181              3140
# 4                             431              2313              6507
# ...                           ...               ...               ...
# 9012                            0                32                60
# 9013                            0                32                60
# 9014                           44               392               787
# 9015                          219              1668              3494
# 9016                          263              2060              4281
#
#       Cluster     ClusterLabel
# 0           0  Sensitive Areas
# 1           0  Sensitive Areas
# 2           0  Sensitive Areas
# 3           0  Sensitive Areas
# 4           0  Sensitive Areas
# ...       ...              ...
# 9012        0  Sensitive Areas
# 9013        0  Sensitive Areas
# 9014        0  Sensitive Areas
# 9015        0  Sensitive Areas
# 9016        0  Sensitive Areas
#
# [8824 rows x 35 columns]
#
# Cluster 1 DataFrame:
#        STATE/UT Name District Name  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28    ANDHRA PRADESH         TOTAL  2001    2602               1555
# 351   MADHYA PRADESH         TOTAL  2001    2425               2870
# 397      MAHARASHTRA         TOTAL  2001    2839               1454
# 529        RAJASTHAN         TOTAL  2001    1259               1923
# 573       TAMIL NADU         TOTAL  2001    1662               2204
# ...              ...           ...   ...     ...                ...
# 8335           BIHAR         TOTAL  2012    3566               5452
# 8611  MADHYA PRADESH         TOTAL  2012    2373               2332
# 8657     MAHARASHTRA         TOTAL  2012    2712               2168
# 8806       RAJASTHAN         TOTAL  2012    1461               1538
# 8938   UTTAR PRADESH         TOTAL  2012    4966               4811
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# 351                                         125  2851               0
# 397                                         101  1302               0
# 529                                          63  1049               0
# 573                                          19   423               0
# ...                                         ...   ...             ...
# 8335                                        285   927               0
# 8611                                        114  3425               0
# 8657                                        171  1839               0
# 8806                                         98  2049               0
# 8938                                       1410  1963               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  DOWRY DEATHS  \
# 28           871                    1182  ...           420
# 351         2851                     956  ...           609
# 397         1302                     985  ...           308
# 529         1049                    2718  ...           376
# 573          423                     952  ...           191
# ...          ...                     ...  ...           ...
# 8335         927                    4807  ...          1275
# 8611        3425                    1302  ...           743
# 8657        1839                    1583  ...           329
# 8806        2049                    3243  ...           478
# 8938        1963                    8878  ...          2244
#
#       ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 28                                                 3544
# 351                                                7063
# 397                                                2823
# 529                                                2878
# 573                                                1773
# ...                                                 ...
# 8335                                                118
# 8611                                               6655
# 8657                                               3935
# 8806                                               2352
# 8938                                               3247
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 28                          2271                                 5791
# 351                          751                                 2562
# 397                         1120                                 6090
# 529                           56                                 5532
# 573                         1012                                  815
# ...                          ...                                  ...
# 8335                          37                                 3686
# 8611                         774                                 3988
# 8657                        1294                                 7415
# 8806                          18                                13312
# 8938                           8                                 7661
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 28                                              7
# 351                                             0
# 397                                             1
# 529                                             1
# 573                                            14
# ...                                           ...
# 8335                                            4
# 8611                                            6
# 8657                                            0
# 8806                                            0
# 8938                                            0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES  \
# 28                           7400             34344            130089
# 351                          3297             85143            181741
# 397                          8993             42963            171233
# 529                          4221             62347            155185
# 573                          8550             76468            154801
# ...                           ...               ...               ...
# 8335                         4631             35421            146614
# 8611                         7721            114585            220335
# 8657                        13311             46668            202700
# 8806                         8284             70240            170948
# 8938                        14406             68538            198093
#
#       Cluster    ClusterLabel
# 28          1  Moderate Areas
# 351         1  Moderate Areas
# 397         1  Moderate Areas
# 529         1  Moderate Areas
# 573         1  Peaceful Areas
# ...       ...             ...
# 8335        1  Moderate Areas
# 8611        1  Moderate Areas
# 8657        1  Moderate Areas
# 8806        1  Moderate Areas
# 8938        1  Moderate Areas
#
# [62 rows x 35 columns]
#
# Cluster 2 DataFrame:
#      STATE/UT Name   District Name  YEAR  MURDER  ATTEMPT TO MURDER  \
# 115          BIHAR           TOTAL  2001    3643               3419
# 169        GUJARAT           TOTAL  2001    1226                537
# 285      KARNATAKA           TOTAL  2001    1626               1475
# 302         KERALA           TOTAL  2001     472                615
# 370    MAHARASHTRA          MUMBAI  2001     295                200
# ...            ...             ...   ...     ...                ...
# 8630   MAHARASHTRA   MUMBAI COMMR.  2012     215                170
# 8734        ODISHA           TOTAL  2012    1548               1879
# 8851    TAMIL NADU           TOTAL  2012    1949               2954
# 8982   WEST BENGAL           TOTAL  2012    2252               2854
# 8997      DELHI UT  DELHI UT TOTAL  2012     521                439
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 115                                         250   888               0
# 169                                          94   286               0
# 285                                          74   293               0
# 302                                         111   562               0
# 370                                           6   127               0
# ...                                         ...   ...             ...
# 8630                                          9   232               0
# 8734                                         54  1458               0
# 8851                                         44   737               0
# 8982                                        522  2046               0
# 8997                                         82   706               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  DOWRY DEATHS  \
# 115          888                    2159  ...           859
# 169          286                     998  ...            67
# 285          293                     559  ...           220
# 302          562                     183  ...            27
# 370          127                     148  ...            18
# ...          ...                     ...  ...           ...
# 8630         232                     212  ...            11
# 8734        1458                    1542  ...           525
# 8851         737                    1945  ...           110
# 8982        2046                    5117  ...           593
# 8997         706                    3970  ...           134
#
#       ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 115                                                 562
# 169                                                 756
# 285                                                1665
# 302                                                1942
# 370                                                 274
# ...                                                 ...
# 8630                                                614
# 8734                                               4187
# 8851                                               1494
# 8982                                               3345
# 8997                                                727
#
#       INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 115                           21                                 1558
# 169                          111                                 3667
# 285                           81                                 1755
# 302                           81                                 2561
# 370                           44                                  198
# ...                          ...                                  ...
# 8630                         235                                  388
# 8734                         304                                 2638
# 8851                         382                                 1965
# 8982                         556                                19865
# 8997                         208                                 1985
#
#       IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# 115                                            83
# 169                                             0
# 285                                             0
# 302                                             0
# 370                                             0
# ...                                           ...
# 8630                                            0
# 8734                                            0
# 8851                                            0
# 8982                                           12
# 8997                                            0
#
#       CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES  \
# 115                          2406             36667             88432
# 169                          2924             50719            103419
# 285                           100             47301            109098
# 302                             0             54544            103847
# 370                           709              6095             28968
# ...                           ...               ...               ...
# 8630                          621              6423             30508
# 8734                         3605             22203             67957
# 8851                        15499            124176            200474
# 8982                         4385             64482            161427
# 8997                          913             15408             54287
#
#       Cluster     ClusterLabel
# 115         2   Moderate Areas
# 169         2   Peaceful Areas
# 285         2   Peaceful Areas
# 302         2   Peaceful Areas
# 370         2  Sensitive Areas
# ...       ...              ...
# 8630        2  Sensitive Areas
# 8734        2   Peaceful Areas
# 8851        2   Peaceful Areas
# 8982        2   Moderate Areas
# 8997        2   Peaceful Areas
#
# [131 rows x 35 columns]

# %%
x = "District Name"
try:
    y = float(x)
except ValueError:
    print("Error: could not convert string to float")
# Out:
# Error: could not convert string to float

# %%
print(cluster_characteristics.columns)
# Out:
# Index(['YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
# Assuming 'crime_data' is your DataFrame
crime_data = pd.read_csv('01_District_wise_crimes_committed_IPC_2001_2012.csv')
features = crime_data[['District Name', 'MURDER', 'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'KIDNAPPING & ABDUCTION', 'DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT', 'AUTO THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', 'CRUELTY BY HUSBAND OR HIS RELATIVES', 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES']]
 

# Select only numeric columns for clustering
numeric_features = features.select_dtypes(include=[np.number])

# Perform KMeans clustering on numeric features
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
crime_data['Cluster'] = kmeans.fit_predict(numeric_features)

# Principal Component Analysis (PCA) for visualization
pca = PCA(n_components=2)
principal_components = pca.fit_transform(numeric_features)
pc_df = pd.DataFrame(data=principal_components, columns=['Principal Component 1', 'Principal Component 2'])
pc_df['Cluster'] = crime_data['Cluster']

# Visualize Clusters
plt.figure(figsize=(15, 8))
sns.scatterplot(x='Principal Component 1', y='Principal Component 2', hue='Cluster', data=pc_df)
plt.title('PCA - Clusters Visualization')
plt.show()

# Convert 'District Name' to string
crime_data['District Name'] = crime_data['District Name'].astype(str)

# Analyzing Cluster Characteristics
cluster_characteristics = crime_data.groupby(['Cluster', 'District Name']).mean()

# Reset index to make 'District Name' a regular column
cluster_characteristics = cluster_characteristics.reset_index()

# Melt the DataFrame to have 'Crime Type', 'Cluster', and 'Average Crime Rate' columns
melted_data = cluster_characteristics_transposed.melt(id_vars='index', var_name='Cluster', value_name='Average Crime Rate')


melted_data.columns = ['Crime Type', 'Cluster', 'Average Crime Rate']

melted_data['Cluster'] = melted_data['Cluster'].astype(str)
# 1. What is impacting more crimes in sensitive areas?
# Plotting crime distribution in sensitive areas
plt.figure(figsize=(15, 8))
sns.barplot(x='Crime Type', y='Average Crime Rate', hue='Cluster', data=melted_data)
plt.title('Crime Distribution in Sensitive Areas')
plt.xlabel('Crime Type')
plt.ylabel('Average Crime Rate')
plt.xticks(rotation=45, ha='right')
plt.show()

# 2. What needs to be done to reduce crime?
# Calculate correlation matrix
correlation_matrix = crime_data[features.columns].corr()

# Plotting correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Crime Features')
plt.show()

# Convert 'Cluster' to string
top_districts['Cluster'] = top_districts['Cluster'].astype(str)

# 3. Most safe and unsafe districts
# Visualizing Safe and Unsafe Districts (Top 10 for each Cluster)
plt.figure(figsize=(15, 8))
sns.barplot(x='District Name', y='TOTAL IPC CRIMES', hue='Cluster', data=top_districts.sort_values('TOTAL IPC CRIMES', ascending=False))
plt.title('Top 10 Unsafe Districts for Each Cluster')
plt.xlabel('District Name')
plt.ylabel('Total IPC CRIMES')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Cluster')
plt.show()
